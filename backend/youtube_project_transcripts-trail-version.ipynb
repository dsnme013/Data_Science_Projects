# %%
pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in c:\users\nishitha sai\anaconda3\lib\site-packages (0.28.0)
# Requirement already satisfied: tqdm in c:\users\nishitha sai\anaconda3\lib\site-packages (from openai==0.28) (4.66.2)
# Requirement already satisfied: aiohttp in c:\users\nishitha sai\anaconda3\lib\site-packages (from openai==0.28) (3.9.5)
# Requirement already satisfied: requests>=2.20 in c:\users\nishitha sai\anaconda3\lib\site-packages (from openai==0.28) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests>=2.20->openai==0.28) (2022.9.14)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai==0.28) (21.4.0)
# Requirement already satisfied: colorama in c:\users\nishitha sai\anaconda3\lib\site-packages (from tqdm->openai==0.28) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install deep-translator
# Out:
# Requirement already satisfied: deep-translator in c:\users\nishitha sai\anaconda3\lib\site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from deep-translator) (4.11.1)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from deep-translator) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask flask-cors google-api-python-client youtube-transcript-api googletrans openai
# Out:
# Requirement already satisfied: flask in c:\users\nishitha sai\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: flask-cors in c:\users\nishitha sai\anaconda3\lib\site-packages (4.0.1)
# Requirement already satisfied: google-api-python-client in c:\users\nishitha sai\anaconda3\lib\site-packages (2.73.0)
# Requirement already satisfied: youtube-transcript-api in c:\users\nishitha sai\anaconda3\lib\site-packages (0.6.2)
# Requirement already satisfied: googletrans in c:\users\nishitha sai\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: openai in c:\users\nishitha sai\anaconda3\lib\site-packages (0.28.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\nishitha sai\anaconda3\lib\site-packages (from flask) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\nishitha sai\anaconda3\lib\site-packages (from flask) (2.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from flask) (8.0.4)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-api-python-client) (2.16.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: requests in c:\users\nishitha sai\anaconda3\lib\site-packages (from youtube-transcript-api) (2.28.1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\nishitha sai\anaconda3\lib\site-packages (from googletrans) (0.13.3)
# Requirement already satisfied: idna==2.* in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Requirement already satisfied: certifi in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2022.9.14)
# Requirement already satisfied: hstspreload in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2024.7.1)
# Requirement already satisfied: sniffio in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (1.2.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: chardet==3.* in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\nishitha sai\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)
# Requirement already satisfied: aiohttp in c:\users\nishitha sai\anaconda3\lib\site-packages (from openai) (3.9.5)
# Requirement already satisfied: tqdm in c:\users\nishitha sai\anaconda3\lib\site-packages (from openai) (4.66.2)
# Requirement already satisfied: colorama in c:\users\nishitha sai\anaconda3\lib\site-packages (from click>=5.1->flask) (0.4.5)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.58.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nishitha sai\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask) (2.1.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests->youtube-transcript-api) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from requests->youtube-transcript-api) (1.26.11)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\nishitha sai\anaconda3\lib\site-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\nishitha sai\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
# from flask import Flask, request, jsonify
# from flask_cors import CORS
# from googleapiclient.discovery import build
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound
# from deep_translator import GoogleTranslator
# import openai
# import urllib.parse

# app = Flask(__name__)
# CORS(app)
# YOUTUBE_API_KEY = 'AIzaSyCbNY1pb4V-NVh8XfuzEmcbS268ebGJpPs'
# OPENAI_API_KEY = 'sk-proj-5BaJxroeVZF0WgTiIA2IT3BlbkFJbLG9nIMa5JCUlJGguakh'
# openai.api_key = OPENAI_API_KEY
# # MAX_YOUTUBE_VIDEOS=50 # This is a configurable parameter based on the number videos in a playlist

# youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)

# def get_video_id_from_url(url):
#     parsed_url = urllib.parse.urlparse(url)
#     query_params = urllib.parse.parse_qs(parsed_url.query)
#     return query_params.get('v')[0] if 'v' in query_params else None

# def get_playlist_id_from_url(url):
#     parsed_url = urllib.parse.urlparse(url)
#     query_params = urllib.parse.parse_qs(parsed_url.query)
#     return query_params.get('list')[0] if 'list' in query_params else None

# def get_transcript(video_id):
#     try:
#         transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
#         return transcript
#     except NoTranscriptFound:
#         return None
#     except TranscriptsDisabled:
#         return None

# def get_transcript_auto(video_id):
#     try:
#         transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
#         for transcript in transcript_list:
#             if transcript.language_code != 'en':
#                 return transcript.fetch()
#         return None
#     except Exception as e:
#         print(f"Could not retrieve transcript for video ID {video_id}: {e}")
#         return None

# def translate_transcript(transcript, target_language='en'):
#     text = ' '.join([entry['text'] for entry in transcript])
#     translated_text = GoogleTranslator(source='auto', target=target_language).translate(text)
#     return [{'text': translated_text}]

# def analyze_sentiment(text):
#     response = openai.ChatCompletion.create(
#         model="gpt-3.5-turbo",
#         messages=[
#             {"role": "system", "content": "You are a helpful assistant."},
#             {"role": "user", "content": f"Analyze the sentiment as positive,negative or nuetral for the following text: {text}"}
#         ]
#     )
#     return response.choices[0].message['content'].strip()

# def analyze_transcript(transcript):
#     text = ' '.join(entry['text'] for entry in transcript)
#     sentiment = analyze_sentiment(text)
    
#     if "positive" in sentiment.lower():
#         return "Positive"
#     elif "negative" in sentiment.lower():
#         return "Negative"
#     else:
#         return "Neutral"

# @app.route('/analyze', methods=['GET'])
# def analyze():
#     url = request.args.get('url')
#     video_id = get_video_id_from_url(url)
#     playlist_id = get_playlist_id_from_url(url)
#     results = []

#     if playlist_id:
#         next_page_token = None
#         while True:
#             playlist_response = youtube.playlistItems().list(
#                 part='snippet',
#                 playlistId=playlist_id,
#                 maxResults=50, 
#                 pageToken=next_page_token
#             ).execute()

#             for item in playlist_response.get('items', []):
#                 video_id = item['snippet']['resourceId']['videoId']
#                 title = item['snippet']['title']
#                 thumbnail = item['snippet']['thumbnails']['default']['url']
#                 transcript = get_transcript(video_id)
#                 if not transcript:
#                     transcript = get_transcript_auto(video_id)
#                     if transcript:
#                         transcript = translate_transcript(transcript)
#                 if transcript:
#                     sentiment = analyze_transcript(transcript)
#                     results.append({
#                         'title': title,
#                         'thumbnail': thumbnail,
#                         'sentiment': sentiment
#                     })

#             next_page_token = playlist_response.get('nextPageToken')
#             if not next_page_token:
#                 break
#     elif video_id:
#         video_response = youtube.videos().list(
#             part='snippet',
#             id=video_id
#         ).execute()

#         if video_response['items']:
#             video_details = video_response['items'][0]['snippet']
#             title = video_details['title']
#             thumbnail = video_details['thumbnails']['default']['url']
#             transcript = get_transcript(video_id)
#             if not transcript:
#                 transcript = get_transcript_auto(video_id)
#                 if transcript:
#                     transcript = translate_transcript(transcript)
#             if transcript:
#                 sentiment = analyze_transcript(transcript)
#                 results.append({
#                     'title': title,
#                     'thumbnail': thumbnail,
#                     'sentiment': sentiment
#                 })
#         else:
#             return jsonify({'error': 'Video not found'}), 404
#     else:
#         return jsonify({'error': 'Invalid URL'}), 400

#     return jsonify(results)

# if __name__ == '__main__':
#     app.run(debug=False, port=5000)

# %%
import os
from flask import Flask, request, jsonify
from flask_cors import CORS
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound
from deep_translator import GoogleTranslator
import openai
import urllib.parse

app = Flask(__name__)
CORS(app)

YOUTUBE_API_KEY = 'AIzaSyCbNY1pb4V-NVh8XfuzEmcbS268ebGJpPs'
OPENAI_API_KEY = 'sk-proj-5BaJxroeVZF0WgTiIA2IT3BlbkFJbLG9nIMa5JCUlJGguakh'

youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)

def get_video_id_from_url(url):
    parsed_url = urllib.parse.urlparse(url)
    query_params = urllib.parse.parse_qs(parsed_url.query)
    return query_params.get('v')[0] if 'v' in query_params else None

def get_playlist_id_from_url(url):
    parsed_url = urllib.parse.urlparse(url)
    query_params = urllib.parse.parse_qs(parsed_url.query)
    return query_params.get('list')[0] if 'list' in query_params else None

def get_transcript(video_id):
    try:
        return YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
    except (NoTranscriptFound, TranscriptsDisabled):
        return None

def get_transcript_auto(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        for transcript in transcript_list:
            if transcript.language_code != 'en':
                return transcript.fetch()
    except Exception as e:
        print(f"Could not retrieve transcript for video ID {video_id}: {e}")
    return None

def translate_transcript(transcript, target_language='en'):
    text = ' '.join([entry['text'] for entry in transcript])
    return [{'text': GoogleTranslator(source='auto', target=target_language).translate(text)}]

def analyze_sentiment(text):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"Analyze the sentiment as positive, negative, or neutral for the following text: {text}"}
        ]
    )
    return response.choices[0].message['content'].strip()

def analyze_transcript(transcript):
    text = ' '.join(entry['text'] for entry in transcript)
    sentiment = analyze_sentiment(text)
    if "positive" in sentiment.lower():
        return "Positive"
    elif "negative" in sentiment.lower():
        return "Negative"
    else:
        return "Neutral"

# %%
# youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)

# def get_video_id_from_url(url):
#     parsed_url = urllib.parse.urlparse(url)
#     query_params = urllib.parse.parse_qs(parsed_url.query)
#     return query_params.get('v')[0] if 'v' in query_params else None

# def get_playlist_id_from_url(url):
#     parsed_url = urllib.parse.urlparse(url)
#     query_params = urllib.parse.parse_qs(parsed_url.query)
#     return query_params.get('list')[0] if 'list' in query_params else None

# def get_transcript(video_id):
#     try:
#         return YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
#     except (NoTranscriptFound, TranscriptsDisabled):
#         return None

# def get_transcript_auto(video_id):
#     try:
#         transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
#         for transcript in transcript_list:
#             if transcript.language_code != 'en':
#                 return transcript.fetch()
#     except Exception as e:
#         print(f"Could not retrieve transcript for video ID {video_id}: {e}")
#     return None

# def translate_transcript(transcript, target_language='en'):
#     text = ' '.join([entry['text'] for entry in transcript])
#     return [{'text': GoogleTranslator(source='auto', target=target_language).translate(text)}]

# def analyze_sentiment(text):
#     response = openai.ChatCompletion.create(
#         model="gpt-3.5-turbo",
#         messages=[
#             {"role": "system", "content": "You are a helpful assistant."},
#             {"role": "user", "content": f"Analyze the sentiment as positive, negative, or neutral for the following text: {text}"}
#         ]
#     )
#     return response.choices[0].message['content'].strip()

# def analyze_transcript(transcript):
#     text = ' '.join(entry['text'] for entry in transcript)
#     sentiment = analyze_sentiment(text)
#     if "positive" in sentiment.lower():
#         return "Positive"
#     elif "negative" in sentiment.lower():
#         return "Negative"
#     else:
#         return "Neutral"

# @app.route('/')
# def index():
#     return "Welcome to the YouTube Transcript Sentiment Analysis API"

# # @app.route('/favicon.ico')
# # def favicon():
# #     return send_from_directory(os.path.join(app.root_path, 'static'), 'favicon.ico', mimetype='image/vnd.microsoft.icon')

# @app.route('/analyze', methods=['GET'])
# def analyze():
#     url = request.args.get('url')
#     if not url:
#         return jsonify({'error': 'URL is required'}), 400

#     video_id = get_video_id_from_url(url)
#     playlist_id = get_playlist_id_from_url(url)
#     results = []

#     if playlist_id:
#         next_page_token = None
#         while True:
#             playlist_response = youtube.playlistItems().list(
#                 part='snippet',
#                 playlistId=playlist_id,
#                 maxResults=50, 
#                 pageToken=next_page_token
#             ).execute()

#             for item in playlist_response.get('items', []):
#                 video_id = item['snippet']['resourceId']['videoId']
#                 title = item['snippet']['title']
#                 thumbnail = item['snippet']['thumbnails']['default']['url']
#                 transcript = get_transcript(video_id)
#                 if not transcript:
#                     transcript = get_transcript_auto(video_id)
#                     if transcript:
#                         transcript = translate_transcript(transcript)
#                 if transcript:
#                     sentiment = analyze_transcript(transcript)
#                     results.append({
#                         'title': title,
#                         'thumbnail': thumbnail,
#                         'sentiment': sentiment
#                     })

#             next_page_token = playlist_response.get('nextPageToken')
#             if not next_page_token:
#                 break
#     elif video_id:
#         video_response = youtube.videos().list(
#             part='snippet',
#             id=video_id
#         ).execute()

#         if video_response['items']:
#             video_details = video_response['items'][0]['snippet']
#             title = video_details['title']
#             thumbnail = video_details['thumbnails']['default']['url']
#             transcript = get_transcript(video_id)
#             if not transcript:
#                 transcript = get_transcript_auto(video_id)
#                 if transcript:
#                     transcript = translate_transcript(transcript)
#             if transcript:
#                 sentiment = analyze_transcript(transcript)
#                 results.append({
#                     'title': title,
#                     'thumbnail': thumbnail,
#                     'sentiment': sentiment
#                 })
#         else:
#             return jsonify({'error': 'Video not found'}), 404
#     else:
#         return jsonify({'error': 'Invalid URL'}), 400

#     return jsonify(results)

# if __name__ == '__main__':
#     app.run(debug=False, port=5000)

# %%
import os
from flask import Flask, request, jsonify
from flask_cors import CORS
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound
from deep_translator import GoogleTranslator
import openai
import urllib.parse

app = Flask(__name__)           
CORS(app)

YOUTUBE_API_KEY = 'AIzaSyCbNY1pb4V-NVh8XfuzEmcbS268ebGJpPs'
OPENAI_API_KEY = 'sk-proj-5BaJxroeVZF0WgTiIA2IT3BlbkFJbLG9nIMa5JCUlJGguakh'

youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)      

def get_video_id_from_url(url):
    parsed_url = urllib.parse.urlparse(url)
    query_params = urllib.parse.parse_qs(parsed_url.query)
    return query_params.get('v')[0] if 'v' in query_params else None               .  

def get_playlist_id_from_url(url):
    parsed_url = urllib.parse.urlparse(url)
    query_params = urllib.parse.parse_qs(parsed_url.query)
    return query_params.get('list')[0] if 'list' in query_params else None

def get_transcript(video_id):
    try:
        return YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
    except (NoTranscriptFound, TranscriptsDisabled):
        return None

def get_transcript_auto(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        for transcript in transcript_list:
            if transcript.language_code != 'en':
                return transcript.fetch()
    except Exception as e:
        print(f"Could not retrieve transcript for video ID {video_id}: {e}")
    return None

def translate_transcript(transcript, target_language='en'):
    text = ' '.join([entry['text'] for entry in transcript])
    return [{'text': GoogleTranslator(source='auto', target=target_language).translate(text)}]

def analyze_sentiment(text):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"Analyze the sentiment as positive, negative, or neutral for the following text: {text}"}
        ]
    )
    return response.choices[0].message['content'].strip()

def analyze_transcript(transcript):
    text = ' '.join(entry['text'] for entry in transcript)
    sentiment = analyze_sentiment(text)
    if "positive" in sentiment.lower():
        return "Positive"
    elif "negative" in sentiment.lower():
        return "Negative"
    else:
        return "Neutral"

@app.route('/')
def index():
    return "Welcome to the YouTube Transcript Sentiment Analysis API" 


            

/.p589`1234567nalyze', methods=['GET'])
def analyze():
    url = request.args.get('url')
    if not url:
        return jsonify({'error': 'URL is required'}), 400

    video_id = get_video_id_from_url(url)
    playlist_id = get_playlist_id_from_url(url)
    results = []

    if playlist_id:
        next_page_token = None
        while True:
            playlist_response = youtube.playlistItems().list(
                part='snippet',
                playlistId=playlist_id,
                maxResults=50, 
                pageToken=next_page_token
            ).execute()

            for item in playlist_response.get('items', []):
                video_id = item['snippet']['resourceId']['videoId']
                title = item['snippet']['title']
                thumbnail = item['snippet']['thumbnails']['default']['url']
                transcript = get_transcript(video_id)
                if not transcript:
                    transcript = get_transcript_auto(video_id)
                    if transcript:
                        transcript = translate_transcript(transcript)
                if transcript:
                    sentiment = analyze_transcript(transcript)
                    results.append({
                        'title': title,
                        'thumbnail': thumbnail,
                        'sentiment': sentiment,
                        'video_id': video_id
                    })

            next_page_token = playlist_response.get('nextPageToken')
            if not next_page_token:
                break
    elif video_id:
        video_response = youtube.videos().list(
            part='snippet',
            id=video_id
        ).execute()

        if video_response['items']:
            video_details = video_response['items'][0]['snippet']
            title = video_details['title']
            thumbnail = video_details['thumbnails']['default']['url']
            transcript = get_transcript(video_id)
            if not transcript:
                transcript = get_transcript_auto(video_id)
                if transcript:
                    transcript = translate_transcript(transcript)
            if transcript:
                sentiment = analyze_transcript(transcript)
                results.append({
                    'title': title,
                    'thumbnail': thumbnail,
                    'sentiment': sentiment,
                    'video_id': video_id
                })
        else:
            return jsonify({'error': 'Video not found'}), 404
    else:
        return jsonify({'error': 'Invalid URL'}), 400

    return jsonify(results)
if __name__ == '__main__':
    app.run(debug=False, port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
