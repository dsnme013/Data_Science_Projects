# %%
import os
os.environ['OPENAI_API_KEY'] = ''

# %%
from langchain.llms import OpenAI

from langchain.prompts import PromptTemplate

# %%
model = OpenAI()

# %%
prompt_template = PromptTemplate.from_template(
    "As a {role} tellme about {content}."
)

# %%
filled_prompt = prompt_template.format(role="Physics Teacher", content="Kinematics")
print(filled_prompt)
# Out:
# As a Physics Teacher specilization in Kinematics.

# %%
prompt_and_model = prompt_template | model

# %%
query = "Tell me about newton law of motion."

# %%
output = prompt_and_model.invoke({"role": "Physics Teacher","content":"Kinematics"})

# %%
print(output)
# Out:
# Kinematics is a branch of physics that deals with the study of motion of objects without considering the forces that cause the motion. As a Physics teacher specializing in kinematics, my role is to help students understand the concepts, principles, and equations that govern the motion of objects. I am responsible for teaching students how to analyze and solve problems related to motion using mathematical techniques.
#
# One of the key topics in kinematics is position, velocity, and acceleration. I will teach my students about displacement, which is the change in position of an object, and how it is related to velocity and acceleration. Students will also learn how to calculate average and instantaneous velocity and acceleration, and how to use graphs to represent these quantities.
#
# Another important aspect of kinematics is projectile motion. I will guide my students to understand how objects move in a curved path when they are thrown or launched into the air. They will learn how to analyze the motion of projectiles using equations and vector diagrams.
#
# In addition, I will cover topics such as uniform and non-uniform motion, relative motion, and circular motion. Students will learn about the different types of motion and how to apply the equations of kinematics to solve problems related to these motions.
#
# As a Physics teacher specializing in kinematics, I will use various teaching

# %%
from langchain.output_parsers.json import SimpleJsonOutputParser

# Create a JSON prompt
json_prompt = PromptTemplate.from_template(
    "Return a JSON object with `birthdate` and `birthplace` key that answers the following question: {question}"
)

# Initialize the JSON parser
json_parser = SimpleJsonOutputParser()

# Create a chain with the prompt, model, and parser
json_chain = json_prompt | model | json_parser

# Stream through the results
result_list = json_chain.invoke({"question": "When and where was Mahatma Gandhi born?"})

# The result is a list of JSON-like dictionaries
print(result_list)
# Out:
# {'birthdate': 'October 2, 1869', 'birthplace': 'Porbandar, Gujarat, India'}
